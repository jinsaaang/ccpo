# %%
import numpy as np
from layers import multi_cp as MultiDim_CP
from models.lstm import LSTMModel

# %%
fit_func = LSTMModel()

# %%
print(f'######### Wind 2d data #########')
alpha = 0.1
tr_frac = 0.85 # Fraction of data to use for training
data_dict = np.load('data.npz')
Xfull, Yfull = data_dict['Xfull'], data_dict['Yfull']
ntr = int(tr_frac * len(Xfull))
Xtr, Xte, Ytr, Yte = Xfull[:ntr], Xfull[ntr:], Yfull[:ntr], Yfull[ntr:]
s=1
smallT = False
past_window = 10
bins = 5
B = 15 
fit_func = LSTMModel()

CP_obj = MultiDim_CP.SPCI_and_EnbPI(Xtr, Xte, Ytr, Yte, fit_func)
CP_obj.bins = bins
CP_obj.fit_bootstrap_models_online_multistep(B=B,stride=s)
CP_obj.compute_Widths_Ensemble_online(alpha=alpha, stride=s, smallT=smallT, 
                                        past_window=past_window, use_SPCI=True)

mean_cov, mean_size = CP_obj.get_results()
coverages_all, width_all = CP_obj.coverages_all, CP_obj.width_all
print(f'################################################')
print(f'Average coverage: {mean_cov:.2f}')
print(f'Average size: {mean_size:.2e}')
# Out:
# ######### Wind 2d data #########
# 1/1 multi-step: finish Fitting 15 Bootstrap models, took 0.012454986572265625 secs.
# Leave-one-out residuals computed, took 0.026780366897583008 secs.
# Shape of slided e_t lists is (115, 649)
# Radius of Ellipsoid at test 0 is 2.8293361365795135
# Radius of Ellipsoid at test 5 is 1.5828642547130585
# Radius of Ellipsoid at test 10 is 1.5464096385985613
# Radius of Ellipsoid at test 15 is 1.5385265666991472
# Radius of Ellipsoid at test 20 is 1.5770985204726458
# Radius of Ellipsoid at test 25 is 1.5312152225524187
# Radius of Ellipsoid at test 30 is 1.5515145380049944
# Radius of Ellipsoid at test 35 is 2.015635998919606
# Radius of Ellipsoid at test 40 is 3.518539160490036
# Radius of Ellipsoid at test 45 is 1.5583558399230242
# Radius of Ellipsoid at test 50 is 1.5539390165358782
# Radius of Ellipsoid at test 55 is 1.6690173465758562
# Radius of Ellipsoid at test 60 is 1.555284770205617
# Radius of Ellipsoid at test 65 is 1.5959005672484636
# Radius of Ellipsoid at test 70 is 1.5690338928252459
# Radius of Ellipsoid at test 75 is 1.5728991348296404
# Radius of Ellipsoid at test 80 is 1.5719666797667742
# Radius of Ellipsoid at test 85 is 3.1820556819438934
# Radius of Ellipsoid at test 90 is 3.230824025347829
# Radius of Ellipsoid at test 95 is 1.5694854576140642
# Radius of Ellipsoid at test 100 is 1.5423871595412493
# Radius of Ellipsoid at test 105 is 3.2041064016520977
# Radius of Ellipsoid at test 110 is 1.6171641666442156
# Finish Computing 115 unique Prediction Intervals, took 13.473795890808105 secs.
# Average Coverage is 0.930, Average Ellipsoid Volume is 1.12e+00
# ################################################
# Average coverage: 0.93
# Average size: 1.12e+00

# %%
print(data_dict['Xfull'].shape, data_dict['Yfull'].shape)
# Out:
# (764, 10) (764, 2)

# %%
# Plot predicted on top of true
Yte = Yte; Yhat = CP_obj.Ensemble_pred_interval_centers
cov_mat_est_inv = CP_obj.global_cov_inv
radius = [a-b for a, b in zip(CP_obj.Width_Ensemble.iloc[:, 1], CP_obj.Width_Ensemble.iloc[:, 0])]
idx = plotter.find_furthest_point_idxes(Yhat, n1=10)
x, y = [], []
for i in range(len(Yte)):
    x_i, y_i = plotter.return_ellipsoid(cov_mat_est_inv, radius[i])
    x.append(x_i); y.append(y_i)
x = np.array(x); y = np.array(y)
xlim = [-2.3, 3.8]; ylim = [-1.9, 3.4]
fig = plotter.plot_uncertainty_set(Yte, Yhat, [x, y], idx, 100*mean_cov, mean_size, xlim = xlim, ylim = ylim, box = False)
